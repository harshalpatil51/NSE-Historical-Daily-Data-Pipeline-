# %%
import pandas as pd
from sqlalchemy import create_engine

# PostgreSQL connection string with SSL mode enabled
render_db_url = "postgresql://harshalpatil:Zy2EAJILUiZQsmDonPkQcurww88P95AA@dpg-d3h0ls15pdvs73es4ufg-a.singapore-postgres.render.com:5432/nse_data_pipeline?sslmode=require"

# Create SQLAlchemy engine
engine = create_engine(render_db_url)

# Query 1: Count total symbols
query_total_symbols = "SELECT COUNT(*) AS total_symbols FROM symbols;"
df_total_symbols = pd.read_sql(query_total_symbols, engine)

# Query 2: Latest available date
query_latest_date = "SELECT MAX(date) AS latest_date FROM daily_data;"
df_latest_date = pd.read_sql(query_latest_date, engine)

# Query 3: Nifty value on the latest date (assuming symbol for Nifty is 'NIFTY')
query_nifty_value = """
SELECT date, close AS nifty_close
FROM daily_data
WHERE symbol = 'NIFTY'
ORDER BY date DESC
LIMIT 1;
"""
df_nifty_value = pd.read_sql(query_nifty_value, engine)

# Display the results
print("✅ Total Symbols:\n", df_total_symbols)
print("\n📅 Latest Available Date:\n", df_latest_date)
print("\n📈 Nifty Value on Latest Date:\n", df_nifty_value)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
# ...
